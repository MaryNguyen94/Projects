# %% [markdown]
# # Project: Pet Shelter Analysis (Continute)
# ## Clearn data before analyze (See Days 1).
# ## Update and analyze
# #### Question 1: Count the number of data recorded animals that appear 2 or more times in the dataset?
# #### Question 2: How many animal had found 2 or more times from 2013-2014 and 2017-2018 in dataset?
# #### Question 3: About how many animals are spayed/neutered each month?
# #### Question 4: If spay/neuter for a dog costs 100 and a spay/neuter for a cat costs 50, how much did the shelter spend overtime on these procedures?
# #### Question 5: What are the adoption rates for the following age groups?
# <br>baby: 4 months and less
# <br>young: 5 months - 2 years
# <br>adult: 3 years - 10 years
# <br>senior: 11+

# %% [markdown]
# - Import library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Before analyze

# %% [markdown]
# - Read file aac_intakes.csv and save in 'intake' dataframe

# %%
intake  = pd.read_csv(r'D:\0.JungTalents_Data\JUPYTER NOTEBOOK\Python Analysis\Days(1)\dataset\aac_intakes.csv')
intake
# Out:
#       age_upon_intake animal_id animal_type  \
# 0             8 years   A706918         Dog
# 1           11 months   A724273         Dog
# 2             4 weeks   A665644         Cat
# 3             4 years   A682524         Dog
# 4             2 years   A743852         Dog
# ...               ...       ...         ...
# 80182        10 years   A769067         Dog
# 80183         5 years   A768934         Dog
# 80184         2 years   A769064       Other
# 80185         3 years   A675680         Dog
# 80186          1 year   A680949         Dog
#
#                                         breed            color  \
# 0                    English Springer Spaniel      White/Liver
# 1                                 Basenji Mix      Sable/White
# 2                      Domestic Shorthair Mix           Calico
# 3       Doberman Pinsch/Australian Cattle Dog         Tan/Gray
# 4                      Labrador Retriever Mix        Chocolate
# ...

# %% [markdown]
# - Read file aac_outcomes.csv and save in 'outcome' dataframe

# %%
outcome = pd.read_csv(r'D:\0.JungTalents_Data\JUPYTER NOTEBOOK\Python Analysis\Days(1)\dataset\aac_outcomes.csv')
outcome
# Out:
#       age_upon_outcome animal_id animal_type                          breed  \
# 0              2 weeks   A684346         Cat         Domestic Shorthair Mix
# 1               1 year   A666430         Dog                     Beagle Mix
# 2               1 year   A675708         Dog                       Pit Bull
# 3              9 years   A680386         Dog        Miniature Schnauzer Mix
# 4             5 months   A683115       Other                        Bat Mix
# ...                ...       ...         ...                            ...
# 80676          1 month   A769131         Dog         Labrador Retriever Mix
# 80677          5 years   A665594         Dog  Chihuahua Shorthair/Dachshund
# 80678           1 year   A769120         Dog   Labrador Retriever/Pekingese
# 80679          2 years   A764644         Dog   Blue Lacy/Labrador Retriever
# 80680           1 year   A768726         Dog             Siberian Husky Mix
#
# ...

# %% [markdown]
# - Change data type, remove duplicate rows and rows contain null values (if any)

# %%
# Change data type from object to datetime64
intake[['datetime', 'datetime2']] = intake[['datetime', 'datetime2']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S.%f')
outcome[['date_of_birth', 'datetime', 'monthyear']] = outcome[['date_of_birth', 'datetime', 'monthyear']].apply(pd.to_datetime, format='%Y-%m-%d %H:%M:%S.%f')
print(intake.info())
print('________________________________________')
outcome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80187 entries, 0 to 80186
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age_upon_intake   80187 non-null  object
#  1   animal_id         80187 non-null  object
#  2   animal_type       80187 non-null  object
#  3   breed             80187 non-null  object
#  4   color             80187 non-null  object
#  5   datetime          80187 non-null  datetime64[ns]
#  6   datetime2         80187 non-null  datetime64[ns]
#  7   found_location    80187 non-null  object
#  8   intake_condition  80187 non-null  object
#  9   intake_type       80187 non-null  object
#  10  name              55603 non-null  object
#  11  sex_upon_intake   80186 non-null  object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 7.3+ MB
# None
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80681 entries, 0 to 80680
# ...

# %%
# Remove all identical rows in data
intake = intake.drop_duplicates()
outcome = outcome.drop_duplicates()

# %%
# Check box to show how many rows are there after delete duplicate rows

# %%
# Delete all rows contain null values in 'animal_id' and times columns
intake =  intake.dropna(subset = ['animal_id', 'datetime','datetime2'])
outcome = outcome.dropna(subset = ['animal_id', 'date_of_birth','datetime','monthyear'])

# %%
# Check box to show how many rows each dataframe after delete null values above
# Maybe there are the same

# %% [markdown]
# - Question 1: Count the number of data recorded animals that appear 2 or more times in the dataset?

# %%
# Step 1: select all string values in 'animal_id' column
ids_in = intake.animal_id
ids_out = outcome.animal_id
ids_in
# Out:
# 0        A706918
# 1        A724273
# 2        A665644
# 3        A682524
# 4        A743852
#           ...
# 80182    A769067
# 80183    A768934
# 80184    A769064
# 80185    A675680
# 80186    A680949
# Name: animal_id, Length: 80161, dtype: object

# %%
# Step 2 : select all duplicate rows
# Use '.isin()' to choose each element in series (not list, like dictionary went you call right index values)
# Use '.duplicated()' to select all duplicate values in 'animal_id' column
Duprows_intakes = intake[ids_in.isin(ids_in[ids_in.duplicated()])].sort_values("animal_id")
Duprows_outcomes = outcome[ids_out.isin(ids_out[ids_out.duplicated()])].sort_values("animal_id")

# %%
intake[ids_in.isin(['A684346'])]
ids_in[ids_in.duplicated()]
# Out:
# 357      A731435
# 950      A732478
# 1246     A670462
# 1631     A730944
# 2293     A658843
#           ...
# 80177    A701265
# 80178    A722721
# 80180    A762805
# 80185    A675680
# 80186    A680949
# Name: animal_id, Length: 7796, dtype: object

# %%
# Reuse the dataframe you just checked for duplicate information above to answer this question
print('There are',Duprows_intakes.shape[0],'times that animal in dataset had found 2 times or more')
print('There are',Duprows_outcomes.shape[0],'times that animal in dataset had outcome 2 times or more')
# Out:
# There are 13929 times that animal in dataset had found 2 times or more
# There are 13943 times that animal in dataset had outcome 2 times or more

# %% [markdown]
# - Question 2: How many animal had found 2 or more times from 2013-2014 and 2017-2018 in dataset?

# %%
# Step 1: Choose only 1 for each 'animal_id' values
# Use '.drop_duplicates()' to select unique 'animal_id' values
unique_dup_intake = Duprows_intakes.drop_duplicates(subset = ['animal_id'])
unique_dup_intake
# Out:
#       age_upon_intake animal_id animal_type  \
# 53542         6 years   A006100         Dog
# 74121        15 years   A245945         Dog
# 41024        13 years   A282897         Cat
# 549          14 years   A287017         Dog
# 24845        13 years   A304036         Cat
# ...               ...       ...         ...
# 79810        2 months   A768350         Dog
# 79896        3 months   A768473         Dog
# 80059          1 year   A768566         Dog
# 80134        10 years   A768644         Dog
# 80157         1 month   A768895         Dog
#
#                                                    breed              color  \
# 53542                               Spinone Italiano Mix       Yellow/White
# 74121                             Labrador Retriever Mix                Tan
# 41024                             Domestic Shorthair Mix  Black Smoke/White
# 549                              Chihuahua Shorthair Mix        Black/White
# ...

# %%
# Step 2: Filter data by time
filter_time_in_unique_dup_intake = unique_dup_intake[(unique_dup_intake['datetime'].dt.year == 2013)
                                                    | (unique_dup_intake['datetime'].dt.year == 2014)
                                                    | (unique_dup_intake['datetime'].dt.year == 2017)
                                                    | (unique_dup_intake['datetime'].dt.year == 2018)]
print('There are',filter_time_in_unique_dup_intake.shape[0],'had found 2 times or more')
# Out:
# There are 3242 had found 2 times or more

# %% [markdown]
# - Question 3: About how many animals are spayed/neutered each month?

# %%
##Step 1: Check the first time and the last time that animal's information had record
# Step 1.1 Slice small data to see the 'sex_upon_intake' and 'sex_upon_outcome' column
short_intake = intake[['animal_id', 'sex_upon_intake']]
short_outcome = outcome[['animal_id', 'sex_upon_outcome','datetime']]
# Step 1.2 Drop duplicate values in the fisrt time that animal's information had record
new_short_intake = short_intake.drop_duplicates(subset = ['animal_id'])
# Step 1.3 Select the last date that animal's information had record
new_short_outcome = short_outcome.sort_values(by = 'datetime')
new_short_outcome = new_short_outcome.drop_duplicates(subset = ['animal_id'], keep = 'last')

## Step 2: Intersection 2 dataframe to see the each column values
# Use 'pd.merge' and give parameters 'how ='inner'' 
# to return only the rows in which the left table have matching keys values column in the right table
# and 'on' by column you choose
intersection_data = pd.merge(new_short_intake, new_short_outcome, how ='inner', on =['animal_id'])

## Step 3: Find the animal have not spayed/neutered before
intake_no_sp_ne = intersection_data[(intersection_data.sex_upon_intake != 'Spayed Female')
                     | (intersection_data.sex_upon_intake != 'Neutered Male')]

## Step 4: Find the animal have spayed/neutered after leave in shelter
outcome_sp_ne = intake_no_sp_ne[(intake_no_sp_ne.sex_upon_outcome == 'Neutered Male') 
          | (intake_no_sp_ne.sex_upon_outcome == 'Spayed Female')]

## Step 5: Find the animal have spayed/neutered by staff in shelter
filter_data = outcome_sp_ne[((outcome_sp_ne.sex_upon_intake != 'Neutered Male') 
                    & (outcome_sp_ne.sex_upon_outcome == 'Neutered Male')) 
                | ((outcome_sp_ne.sex_upon_intake != 'Spayed Female') 
                    & (outcome_sp_ne.sex_upon_outcome == 'Spayed Female'))]

## Step 6: Find the first time record in data 
# Use .min() method
first_time_record = filter_data['datetime'].min()

## Step 7: Find the last time record in data
# Use .max() method
last_time_record = filter_data['datetime'].max()

## Step 8: Total times had record in data by month
# Use '.np.timedelta64' calculate datetime data type
month_number_recrd = round((last_time_record - first_time_record)/np.timedelta64(1, 'M'),0)

## Step 9: Convert Timedelta to month int
month_number = (last_time_record - first_time_record)/np.timedelta64(1, 'M')

## Step 10: Caculated the average munber of animal had spayed/neutered by staff
filter_data.shape[0] / month_number
# Out:
# 525.2013764488323

# %% [markdown]
# - Question 4: If spay/neuter for a dog costs 100 and a spay/neuter for a cat costs 50, how much did the shelter spend overtime on these procedures?

# %%
# Step 1: Similar to question 3, but we need column 'animal_type'
short_intake = intake[['animal_id', 'sex_upon_intake']]
short_outcome = outcome[['animal_id', 'sex_upon_outcome','datetime','animal_type']]

new_short_intake = short_intake.drop_duplicates(subset = ['animal_id'])

new_short_outcome = short_outcome.sort_values(by = 'datetime')
new_short_outcome = new_short_outcome.drop_duplicates(subset = ['animal_id'], keep = 'last')

intersection_data = pd.merge(new_short_intake, new_short_outcome, how ='inner', on =['animal_id'])

intake_no_sp_ne = intersection_data[(intersection_data.sex_upon_intake != 'Spayed Female')
                     | (intersection_data.sex_upon_intake != 'Neutered Male')]

outcome_sp_ne = intake_no_sp_ne[(intake_no_sp_ne.sex_upon_outcome == 'Neutered Male') 
          | (intake_no_sp_ne.sex_upon_outcome == 'Spayed Female')]

filter_data = outcome_sp_ne[((outcome_sp_ne.sex_upon_intake != 'Neutered Male') 
                    & (outcome_sp_ne.sex_upon_outcome == 'Neutered Male')) 
                | ((outcome_sp_ne.sex_upon_intake != 'Spayed Female') 
                    & (outcome_sp_ne.sex_upon_outcome == 'Spayed Female'))]

# Step 2: Count each type of animal had record in data and select 'Cat' and 'Dog' type
number_NP = filter_data.groupby(filter_data.animal_type).count()
Cat_number_NP = number_NP.loc['Cat'].animal_id
Dog_number_NP = number_NP.loc['Dog'].animal_id

# Step 3: Calculate the total cost
print(Dog_number_NP * 100 + Cat_number_NP * 50)
# Out:
# 2273600

# %% [markdown]
# - Question 5: What are the adoption rates for the following age groups?
# <br>baby: 4 months and less
# <br>young: 5 months - 2 years
# <br>adult: 3 years - 10 years
# <br>senior: 11+

# %%
# Step 1: Find the animal had adoption in outcome_type
adoption_outcome =  outcome[outcome.outcome_type == 'Adoption']

# Step 2: Drop NA values
adoption_outcome = adoption_outcome[adoption_outcome['age_upon_outcome'].notna()]

# Step 3: Find the data contain 'month' charater
age_upon_months = adoption_outcome[adoption_outcome['age_upon_outcome'].str.contains('month')]

# Step 4: Find the data contain 'year' charater
age_upon_years = adoption_outcome[adoption_outcome['age_upon_outcome'].str.contains("year")]

# Step 5: Combine 2 data frame above, we have animal data upper 1 month
Upper_1_month = pd.concat([age_upon_months, age_upon_years])

# Step 6: Subtract 2 datafames to get animal data below 1 month
Lower_1_month = pd.concat([adoption_outcome,Upper_1_month]).drop_duplicates(keep=False)

# Step 7: Filter the data between baby, young, aldult and senior animal by index number.

list_Baby_index = []
list_Young_index = []
list_Aldult_index = []
list_Senior_index = []

# Find data in age_upon_months datafame
# Step 7.1: Between 1 month and 1 year
for i in range(age_upon_months.shape[0]):
    List_separate_values = age_upon_months.age_upon_outcome.iloc[i].split(' ')
    if int(List_separate_values[0]) >= 5:
        list_Young_index.append(age_upon_months.age_upon_outcome.index[i])
    else:
        list_Baby_index.append(age_upon_months.age_upon_outcome.index[i])
        
# Step 7.2: Upper 1 year
for i in range(age_upon_years.shape[0]):
    List_separate_values = age_upon_years.age_upon_outcome.iloc[i].split(' ')
    if int(List_separate_values[0]) < 3:
        list_Young_index.append(age_upon_years.age_upon_outcome.index[i])
    elif 3 <= int(List_separate_values[0]) <= 10:
        list_Aldult_index.append(age_upon_years.age_upon_outcome.index[i])
    else: 
        list_Senior_index.append(age_upon_years.age_upon_outcome.index[i])
        
# Step 8: Show dataframe
Babyrate = round(100 / adoption_outcome.shape[0] * int(len(list_Baby_index) + Lower_1_month.shape[0]),3)
Youngrate = round(100 / adoption_outcome.shape[0] * int(len(list_Young_index)),3)
Aldultrate = round(100 / adoption_outcome.shape[0] * int(len(list_Aldult_index)),3)
Seniorrate = round(100 / adoption_outcome.shape[0] * int(len(list_Senior_index)),3)

Data = [['Baby rate', Babyrate], ['Young rate', Youngrate], ['Aldult rate', Aldultrate], ['Senior rate', Seniorrate]]
df = pd.DataFrame(Data, columns=['Age_Group', 'Adoption_rates'])
df
# Out:
#      Age_Group  Adoption_rates
# 0    Baby rate          37.435
# 1   Young rate          43.176
# 2  Aldult rate          18.041
# 3  Senior rate           1.347

# %% [markdown]
# BONUS: HOW TO ADD NEW ROWS RECORD IN DATAFRAME

# %%
# Here is a random dataframe
ran_date = np.datetime64('2023-01-01', 'D') + np.random.randint(-365,365,size = 100)
ran_cate = np.random.choice(['A','B','C','D','E','F'], size = 100)
ran_num_int = np.random.randint(100, size = 100)
ran_num_float = np.round(np.random.uniform(0.0, 10.0, size = 100), 2)

ran_df = pd.DataFrame({
    'Date': ran_date,
    'Ran_Category': ran_cate,
    'Random_Int_Number': ran_num_int,
    'Random_Float_Number': ran_num_float})

ran_df
# Out:
#          Date Ran_Category  Random_Int_Number  Random_Float_Number
# 0  2023-01-13            C                 26                 5.60
# 1  2023-08-08            B                 74                 1.04
# 2  2022-04-30            C                  1                 9.13
# 3  2023-05-15            C                 86                 9.42
# 4  2022-02-16            F                 90                 9.12
# ..        ...          ...                ...                  ...
# 95 2023-12-08            C                 53                 6.28
# 96 2023-06-17            B                 63                 6.82
# 97 2022-01-22            B                  3                 7.95
# 98 2023-10-21            E                  1                 0.20
# 99 2022-12-02            E                 82                 3.46
#
# [100 rows x 4 columns]

# %%
ran_df.loc[3] = ['2023-01-01', 'Alpha', 200, 0.1]  # adding a row
ran_df.index = ran_df.index + 1  # shifting index
ran_df = ran_df.sort_index()  # sorting by index
ran_df.head()
# Out:
#         Date Ran_Category  Random_Int_Number  Random_Float_Number
# 1 2023-01-13            C                 26                 5.60
# 2 2023-08-08            B                 74                 1.04
# 3 2022-04-30            C                  1                 9.13
# 4 2023-01-01        Alpha                200                 0.10
# 5 2022-02-16            F                 90                 9.12
